# %% [markdown]
# # Training a weak model for each cluster

# %%
import numpy as np
import os
import pandas as pd
import pprint
import csv
import pickle
import xgboost as xgb
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score

vehicle_types = ['ZVe44', 'ZV573', 'ZV63d', 'ZVfd4', 'ZVa9c', 'ZVa78', 'ZV252']
n_clusters = 36

# %%
def xgboost_train(vehicle_type, cn=0):
    print('vehicle_type :',vehicle_type)
    model_path = '../models/final'
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    model_path = model_path +'/'+  vehicle_type
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    
    status_indicator = list()
    #status:
    ok = 2
    not_found = 0.5
    pos = 1
    neg = 0
    # these are determined optimal settings through tuning, the original tuning result was marked down
    # in the end of this file
    eta = [0.05]
    gamma = [2]
    max_depth = [13]
    
    for i in range(cn, n_clusters):
        
        #load data
        sample = pd.read_csv('../data/final/clusters/' + vehicle_type + '/cluster' + str(i) + '.csv')
        if len(sample) == 0:
            print(vehicle_type+' cluster'+str(i)+': 0 record, skip.')
            status_indicator.append(not_found)
            continue
        sample_= sample[sample.iloc[: , -1]==0]
        if len(sample_) == 0 or len(sample_) == len(sample):
            note = vehicle_type+' cluster'+str(i)+': only has negative samples'
            if len(sample_) == 0:
                status_indicator.append(pos)
                note = vehicle_type+' cluster'+str(i)+': only has positive samples'
            else:
                status_indicator.append(neg)
            print(note)
            continue
        status_indicator.append(ok)
        feature = sample.iloc[:,0:13]
        label = sample.iloc[:,14]
        print(vehicle_type+'cluster' + str(i) + ', shape: ', feature.shape, label.shape)
        
        #xgboost
        best_model = xgb.XGBClassifier()
        best_acc = 0
        for e in eta:
            for m in max_depth:
                for g in gamma:
                    print('[eta=',e, ',gamma=', g, ',max_depth=',m,']')
                    bst = xgb.XGBClassifier( booster ='gbtree', eta = e, max_depth = m, gamma = g, n_jobs = 12)
                    bst.fit(feature, label)
                    acc = bst.score(feature, label)
                    #pred = bst.predict(feature)
                    print("Train Acc: %.2f%%"%(acc*100))
                    #print("prediction: ", pred)
                    feature = sample.iloc[:,0:13]
                    label = sample.iloc[:,14]
                    #cv
                    cv_model = xgb.XGBClassifier( booster ='gbtree', eta = e, max_depth = m, gamma = g, n_jobs = 12)
                    if len(feature) >= 5:
                        kfold = KFold(n_splits = 5, shuffle = False)
                    else:
                        kfold = KFold(n_splits = len(feature), shuffle = False)
                    cv_result = cross_val_score(cv_model, feature, label, cv = kfold, n_jobs = -1)
                    acc = cv_result.mean() * 100
                    #if acc > best_acc:
                    #    best_acc = acc
                    best_model = bst
                    print("CV Acc: %.2f%%, SD: %.2f%%)\n" % (acc, cv_result.std() * 100))
        
        #save the trained model
        with open(model_path+'/trainedXGB' + str(i) + '.pkl', 'wb') as f:
            pickle.dump(best_model,f)
    arr = np.array(status_indicator)
    np.savetxt(model_path+"/status.csv", arr, delimiter=",")

# %%
for vehicle_type in vehicle_types:
        xgboost_train(vehicle_type,0)
    #ZV252 cluster30 only has negative samples
# Out:
# vehicle_type : ZVe44
# ZVe44cluster0, shape:  (580695, 13) (580695,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 76.55%
# CV Acc: 68.32%, SD: 0.72%)
#
# ZVe44cluster1, shape:  (453163, 13) (453163,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 77.87%
# CV Acc: 67.74%, SD: 1.30%)
#
# ZVe44cluster2, shape:  (34899, 13) (34899,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.60%
# CV Acc: 67.12%, SD: 0.92%)
#
# ZVe44cluster3, shape:  (7959, 13) (7959,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.42%
# CV Acc: 76.39%, SD: 3.13%)
#
# ZVe44cluster4, shape:  (104, 13) (104,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.12%
# CV Acc: 59.86%, SD: 22.09%)
#
# ZVe44cluster5, shape:  (214, 13) (214,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.20%
# CV Acc: 77.14%, SD: 20.48%)
#
# ZVe44 cluster6: only has positive samples
# ZVe44 cluster7: 0 record, skip.
# ZVe44 cluster8: only has positive samples
# ZVe44 cluster9: only has positive samples
# ZVe44 cluster10: 0 record, skip.
# ZVe44 cluster11: 0 record, skip.
# ZVe44cluster12, shape:  (9567, 13) (9567,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 94.42%
# CV Acc: 62.72%, SD: 0.99%)
#
# ZVe44cluster13, shape:  (9476, 13) (9476,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.30%
# CV Acc: 62.98%, SD: 0.79%)
#
# ZVe44cluster14, shape:  (690, 13) (690,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.99%
# CV Acc: 58.41%, SD: 7.20%)
#
# ZVe44cluster15, shape:  (255, 13) (255,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.22%
# CV Acc: 67.45%, SD: 10.42%)
#
# ZVe44cluster16, shape:  (189707, 13) (189707,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 82.36%
# CV Acc: 67.76%, SD: 1.50%)
#
# ZVe44cluster17, shape:  (566699, 13) (566699,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 74.43%
# CV Acc: 64.57%, SD: 0.61%)
#
# ZVe44cluster18, shape:  (39541, 13) (39541,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 94.14%
# CV Acc: 67.43%, SD: 1.81%)
#
# ZVe44cluster19, shape:  (5526, 13) (5526,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.52%
# CV Acc: 76.06%, SD: 4.27%)
#
# ZVe44cluster20, shape:  (2388, 13) (2388,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.24%
# CV Acc: 60.17%, SD: 4.29%)
#
# ZVe44cluster21, shape:  (4100, 13) (4100,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.24%
# CV Acc: 63.59%, SD: 3.27%)
#
# ZVe44cluster22, shape:  (245, 13) (245,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.55%
# CV Acc: 63.67%, SD: 13.06%)
#
# ZVe44cluster23, shape:  (111, 13) (111,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.89%
# CV Acc: 56.84%, SD: 7.85%)
#
# ZVe44cluster24, shape:  (86, 13) (86,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 88.30%, SD: 20.73%)
#
# ZVe44cluster25, shape:  (54, 13) (54,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 68.00%, SD: 30.04%)
#
# ZVe44cluster26, shape:  (9, 13) (9,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.89%
# CV Acc: 80.00%, SD: 40.00%)
#
# ZVe44 cluster27: only has positive samples
# ZVe44cluster28, shape:  (5091, 13) (5091,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.45%
# CV Acc: 73.78%, SD: 2.35%)
#
# ZVe44cluster29, shape:  (7727, 13) (7727,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.81%
# CV Acc: 64.22%, SD: 6.22%)
#
# ZVe44cluster30, shape:  (239, 13) (239,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.49%
# CV Acc: 71.38%, SD: 21.30%)
#
# ZVe44cluster31, shape:  (119, 13) (119,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.48%
# CV Acc: 76.56%, SD: 19.05%)
#
# ZVe44cluster32, shape:  (55974, 13) (55974,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.01%
# CV Acc: 67.96%, SD: 1.39%)
#
# ZVe44cluster33, shape:  (79136, 13) (79136,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.28%
# CV Acc: 66.41%, SD: 0.75%)
#
# ZVe44cluster34, shape:  (8256, 13) (8256,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.04%
# CV Acc: 76.33%, SD: 2.63%)
#
# ZVe44cluster35, shape:  (3598, 13) (3598,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.17%
# CV Acc: 78.68%, SD: 2.28%)
#
# vehicle_type : ZV573
# ZV573cluster0, shape:  (1584074, 13) (1584074,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 71.31%
# CV Acc: 63.69%, SD: 0.72%)
#
# ZV573cluster1, shape:  (1000159, 13) (1000159,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 74.78%
# CV Acc: 62.62%, SD: 0.53%)
#
# ZV573cluster2, shape:  (479055, 13) (479055,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 78.91%
# CV Acc: 63.06%, SD: 0.61%)
#
# ZV573cluster3, shape:  (104827, 13) (104827,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.59%
# CV Acc: 70.98%, SD: 0.97%)
#
# ZV573cluster4, shape:  (515, 13) (515,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.83%
# CV Acc: 59.42%, SD: 10.23%)
#
# ZV573cluster5, shape:  (497, 13) (497,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.99%
# CV Acc: 51.33%, SD: 8.11%)
#
# ZV573cluster6, shape:  (77, 13) (77,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 94.81%
# CV Acc: 73.75%, SD: 21.27%)
#
# ZV573cluster7, shape:  (16, 13) (16,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.75%
# CV Acc: 93.33%, SD: 13.33%)
#
# ZV573 cluster8: only has negative samples
# ZV573 cluster9: 0 record, skip.
# ZV573 cluster10: 0 record, skip.
# ZV573 cluster11: 0 record, skip.
# ZV573cluster12, shape:  (20090, 13) (20090,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.40%
# CV Acc: 61.27%, SD: 1.31%)
#
# ZV573cluster13, shape:  (21900, 13) (21900,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.00%
# CV Acc: 57.47%, SD: 1.42%)
#
# ZV573cluster14, shape:  (9304, 13) (9304,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.27%
# CV Acc: 60.09%, SD: 4.35%)
#
# ZV573cluster15, shape:  (2732, 13) (2732,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.90%
# CV Acc: 67.12%, SD: 10.49%)
#
# ZV573cluster16, shape:  (603305, 13) (603305,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 80.14%
# CV Acc: 66.28%, SD: 0.58%)
#
# ZV573cluster17, shape:  (1915427, 13) (1915427,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 77.46%
# CV Acc: 63.46%, SD: 0.78%)
#
# ZV573cluster18, shape:  (1044419, 13) (1044419,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 80.31%
# CV Acc: 66.33%, SD: 0.63%)
#
# ZV573cluster19, shape:  (105606, 13) (105606,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.61%
# CV Acc: 68.13%, SD: 1.45%)
#
# ZV573cluster20, shape:  (8899, 13) (8899,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.28%
# CV Acc: 59.80%, SD: 2.16%)
#
# ZV573cluster21, shape:  (21503, 13) (21503,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.67%
# CV Acc: 64.76%, SD: 2.23%)
#
# ZV573cluster22, shape:  (7955, 13) (7955,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.96%
# CV Acc: 78.34%, SD: 5.04%)
#
# ZV573cluster23, shape:  (3619, 13) (3619,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.23%
# CV Acc: 67.51%, SD: 7.25%)
#
# ZV573cluster24, shape:  (220, 13) (220,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.09%
# CV Acc: 64.55%, SD: 25.29%)
#
# ZV573cluster25, shape:  (456, 13) (456,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.56%
# CV Acc: 82.92%, SD: 18.07%)
#
# ZV573cluster26, shape:  (200, 13) (200,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 80.00%, SD: 25.30%)
#
# ZV573 cluster27: only has negative samples
# ZV573cluster28, shape:  (7056, 13) (7056,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.82%
# CV Acc: 68.76%, SD: 2.59%)
#
# ZV573cluster29, shape:  (11348, 13) (11348,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.03%
# CV Acc: 59.60%, SD: 7.28%)
#
# ZV573cluster30, shape:  (7566, 13) (7566,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.58%
# CV Acc: 78.71%, SD: 7.02%)
#
# ZV573cluster31, shape:  (4694, 13) (4694,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.19%
# CV Acc: 73.63%, SD: 8.07%)
#
# ZV573cluster32, shape:  (186010, 13) (186010,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 84.33%
# CV Acc: 65.47%, SD: 0.85%)
#
# ZV573cluster33, shape:  (233892, 13) (233892,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.78%
# CV Acc: 65.82%, SD: 2.21%)
#
# ZV573cluster34, shape:  (161471, 13) (161471,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.75%
# CV Acc: 83.42%, SD: 0.98%)
#
# ZV573cluster35, shape:  (71146, 13) (71146,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 94.53%
# CV Acc: 71.80%, SD: 1.49%)
#
# vehicle_type : ZV63d
# ZV63dcluster0, shape:  (108672, 13) (108672,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 86.66%
# CV Acc: 71.91%, SD: 1.93%)
#
# ZV63dcluster1, shape:  (23226, 13) (23226,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.06%
# CV Acc: 69.25%, SD: 1.22%)
#
# ZV63dcluster2, shape:  (133460, 13) (133460,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 87.68%
# CV Acc: 69.58%, SD: 1.55%)
#
# ZV63dcluster3, shape:  (38172, 13) (38172,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.31%
# CV Acc: 72.05%, SD: 2.21%)
#
# ZV63dcluster4, shape:  (34, 13) (34,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.06%
# CV Acc: 68.57%, SD: 29.14%)
#
# ZV63dcluster5, shape:  (8, 13) (8,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 62.50%
# CV Acc: 10.00%, SD: 20.00%)
#
# ZV63dcluster6, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 90.83%, SD: 8.41%)
#
# ZV63dcluster7, shape:  (14, 13) (14,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 78.57%
# CV Acc: 80.00%, SD: 40.00%)
#
# ZV63dcluster8, shape:  (32, 13) (32,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 100.00%, SD: 0.00%)
#
# ZV63d cluster9: only has negative samples
# ZV63d cluster10: 0 record, skip.
# ZV63d cluster11: 0 record, skip.
# ZV63dcluster12, shape:  (1138, 13) (1138,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.59%
# CV Acc: 65.64%, SD: 4.86%)
#
# ZV63dcluster13, shape:  (345, 13) (345,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.26%
# CV Acc: 51.30%, SD: 8.23%)
#
# ZV63dcluster14, shape:  (2408, 13) (2408,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.51%
# CV Acc: 58.97%, SD: 3.50%)
#
# ZV63dcluster15, shape:  (662, 13) (662,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.64%
# CV Acc: 65.09%, SD: 10.58%)
#
# ZV63dcluster16, shape:  (42741, 13) (42741,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 94.43%
# CV Acc: 73.29%, SD: 2.31%)
#
# ZV63dcluster17, shape:  (8252, 13) (8252,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.91%
# CV Acc: 66.14%, SD: 2.02%)
#
# ZV63dcluster18, shape:  (202401, 13) (202401,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 87.95%
# CV Acc: 68.13%, SD: 0.68%)
#
# ZV63dcluster19, shape:  (36027, 13) (36027,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.04%
# CV Acc: 70.12%, SD: 0.91%)
#
# ZV63dcluster20, shape:  (282, 13) (282,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.87%
# CV Acc: 78.01%, SD: 11.77%)
#
# ZV63dcluster21, shape:  (28, 13) (28,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 85.71%
# CV Acc: 65.33%, SD: 23.72%)
#
# ZV63dcluster22, shape:  (1069, 13) (1069,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.60%
# CV Acc: 49.57%, SD: 4.30%)
#
# ZV63dcluster23, shape:  (838, 13) (838,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.05%
# CV Acc: 59.30%, SD: 5.03%)
#
# ZV63dcluster24, shape:  (4, 13) (4,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 75.00%
# CV Acc: 75.00%, SD: 43.30%)
#
# ZV63d cluster25: only has positive samples
# ZV63d cluster26: 0 record, skip.
# ZV63d cluster27: only has positive samples
# ZV63dcluster28, shape:  (456, 13) (456,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.68%
# CV Acc: 74.57%, SD: 18.35%)
#
# ZV63dcluster29, shape:  (202, 13) (202,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.01%
# CV Acc: 55.33%, SD: 21.65%)
#
# ZV63dcluster30, shape:  (1321, 13) (1321,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.55%
# CV Acc: 72.60%, SD: 2.45%)
#
# ZV63dcluster31, shape:  (1440, 13) (1440,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.10%
# CV Acc: 76.46%, SD: 7.65%)
#
# ZV63dcluster32, shape:  (6574, 13) (6574,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.11%
# CV Acc: 72.07%, SD: 5.37%)
#
# ZV63dcluster33, shape:  (2665, 13) (2665,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.95%
# CV Acc: 62.10%, SD: 6.47%)
#
# ZV63dcluster34, shape:  (15713, 13) (15713,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.89%
# CV Acc: 60.04%, SD: 6.05%)
#
# ZV63dcluster35, shape:  (18612, 13) (18612,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.69%
# CV Acc: 69.61%, SD: 3.84%)
#
# vehicle_type : ZVfd4
# ZVfd4cluster0, shape:  (34940, 13) (34940,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.55%
# CV Acc: 83.20%, SD: 1.66%)
#
# ZVfd4cluster1, shape:  (7489, 13) (7489,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.32%
# CV Acc: 79.72%, SD: 4.92%)
#
# ZVfd4cluster2, shape:  (11501, 13) (11501,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.23%
# CV Acc: 71.25%, SD: 3.00%)
#
# ZVfd4cluster3, shape:  (4861, 13) (4861,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.59%
# CV Acc: 80.19%, SD: 6.00%)
#
# ZVfd4 cluster4: only has positive samples
# ZVfd4 cluster5: 0 record, skip.
# ZVfd4cluster6, shape:  (2, 13) (2,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 50.00%
# CV Acc: 0.00%, SD: 0.00%)
#
# ZVfd4 cluster7: only has positive samples
# ZVfd4 cluster8: 0 record, skip.
# ZVfd4 cluster9: 0 record, skip.
# ZVfd4 cluster10: 0 record, skip.
# ZVfd4 cluster11: 0 record, skip.
# ZVfd4cluster12, shape:  (415, 13) (415,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.31%
# CV Acc: 64.34%, SD: 4.91%)
#
# ZVfd4cluster13, shape:  (137, 13) (137,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.62%
# CV Acc: 77.28%, SD: 9.35%)
#
# ZVfd4cluster14, shape:  (120, 13) (120,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.00%
# CV Acc: 43.33%, SD: 8.16%)
#
# ZVfd4cluster15, shape:  (41, 13) (41,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 43.89%, SD: 18.54%)
#
# ZVfd4cluster16, shape:  (10447, 13) (10447,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.70%
# CV Acc: 82.62%, SD: 4.51%)
#
# ZVfd4cluster17, shape:  (11133, 13) (11133,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.32%
# CV Acc: 78.98%, SD: 2.94%)
#
# ZVfd4cluster18, shape:  (21975, 13) (21975,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.01%
# CV Acc: 69.78%, SD: 4.84%)
#
# ZVfd4cluster19, shape:  (3140, 13) (3140,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.52%
# CV Acc: 72.71%, SD: 5.47%)
#
# ZVfd4cluster20, shape:  (150, 13) (150,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.33%
# CV Acc: 68.67%, SD: 19.16%)
#
# ZVfd4cluster21, shape:  (78, 13) (78,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.59%
# CV Acc: 62.67%, SD: 26.75%)
#
# ZVfd4cluster22, shape:  (312, 13) (312,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.44%
# CV Acc: 71.54%, SD: 15.36%)
#
# ZVfd4cluster23, shape:  (137, 13) (137,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.70%
# CV Acc: 64.10%, SD: 11.90%)
#
# ZVfd4 cluster24: 0 record, skip.
# ZVfd4 cluster25: 0 record, skip.
# ZVfd4 cluster26: 0 record, skip.
# ZVfd4 cluster27: 0 record, skip.
# ZVfd4cluster28, shape:  (153, 13) (153,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.35%
# CV Acc: 76.69%, SD: 27.88%)
#
# ZVfd4cluster29, shape:  (156, 13) (156,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.36%
# CV Acc: 77.42%, SD: 31.61%)
#
# ZVfd4cluster30, shape:  (304, 13) (304,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.68%
# CV Acc: 84.23%, SD: 15.39%)
#
# ZVfd4cluster31, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.73%
# CV Acc: 88.89%, SD: 17.21%)
#
# ZVfd4cluster32, shape:  (4936, 13) (4936,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.17%
# CV Acc: 80.67%, SD: 2.62%)
#
# ZVfd4cluster33, shape:  (1798, 13) (1798,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.56%
# CV Acc: 74.03%, SD: 6.86%)
#
# ZVfd4cluster34, shape:  (4800, 13) (4800,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.25%
# CV Acc: 65.38%, SD: 8.85%)
#
# ZVfd4cluster35, shape:  (2423, 13) (2423,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.34%
# CV Acc: 72.59%, SD: 11.54%)
#
# vehicle_type : ZVa9c
# ZVa9ccluster0, shape:  (96987, 13) (96987,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.46%
# CV Acc: 74.16%, SD: 0.57%)
#
# ZVa9ccluster1, shape:  (60428, 13) (60428,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.86%
# CV Acc: 69.58%, SD: 2.72%)
#
# ZVa9ccluster2, shape:  (32105, 13) (32105,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.72%
# CV Acc: 67.17%, SD: 0.75%)
#
# ZVa9ccluster3, shape:  (11064, 13) (11064,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.60%
# CV Acc: 72.97%, SD: 2.62%)
#
# ZVa9ccluster4, shape:  (27, 13) (27,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.59%
# CV Acc: 37.33%, SD: 16.79%)
#
# ZVa9ccluster5, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.64%
# CV Acc: 58.89%, SD: 11.97%)
#
# ZVa9ccluster6, shape:  (18, 13) (18,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 77.78%
# CV Acc: 60.00%, SD: 16.16%)
#
# ZVa9c cluster7: 0 record, skip.
# ZVa9c cluster8: 0 record, skip.
# ZVa9c cluster9: 0 record, skip.
# ZVa9c cluster10: 0 record, skip.
# ZVa9c cluster11: 0 record, skip.
# ZVa9ccluster12, shape:  (865, 13) (865,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.38%
# CV Acc: 67.51%, SD: 4.50%)
#
# ZVa9ccluster13, shape:  (1026, 13) (1026,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.15%
# CV Acc: 64.73%, SD: 6.36%)
#
# ZVa9ccluster14, shape:  (320, 13) (320,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.81%
# CV Acc: 62.50%, SD: 8.09%)
#
# ZVa9ccluster15, shape:  (159, 13) (159,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.23%
# CV Acc: 44.54%, SD: 14.63%)
#
# ZVa9ccluster16, shape:  (40402, 13) (40402,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.31%
# CV Acc: 74.35%, SD: 2.62%)
#
# ZVa9ccluster17, shape:  (88835, 13) (88835,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.73%
# CV Acc: 66.89%, SD: 1.97%)
#
# ZVa9ccluster18, shape:  (105813, 13) (105813,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.85%
# CV Acc: 69.27%, SD: 1.70%)
#
# ZVa9ccluster19, shape:  (12398, 13) (12398,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.91%
# CV Acc: 67.38%, SD: 2.13%)
#
# ZVa9ccluster20, shape:  (652, 13) (652,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.23%
# CV Acc: 59.68%, SD: 5.73%)
#
# ZVa9ccluster21, shape:  (1079, 13) (1079,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.52%
# CV Acc: 66.72%, SD: 7.70%)
#
# ZVa9ccluster22, shape:  (1224, 13) (1224,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.28%
# CV Acc: 52.29%, SD: 6.55%)
#
# ZVa9ccluster23, shape:  (733, 13) (733,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.64%
# CV Acc: 61.68%, SD: 4.53%)
#
# ZVa9c cluster24: only has negative samples
# ZVa9c cluster25: 0 record, skip.
# ZVa9c cluster26: only has positive samples
# ZVa9c cluster27: only has negative samples
# ZVa9ccluster28, shape:  (37, 13) (37,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.19%
# CV Acc: 55.71%, SD: 28.29%)
#
# ZVa9ccluster29, shape:  (101, 13) (101,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.05%
# CV Acc: 78.29%, SD: 17.08%)
#
# ZVa9ccluster30, shape:  (121, 13) (121,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.74%
# CV Acc: 63.50%, SD: 10.92%)
#
# ZVa9ccluster31, shape:  (58, 13) (58,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.55%
# CV Acc: 81.06%, SD: 21.31%)
#
# ZVa9ccluster32, shape:  (11333, 13) (11333,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.00%
# CV Acc: 75.66%, SD: 2.96%)
#
# ZVa9ccluster33, shape:  (8988, 13) (8988,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.62%
# CV Acc: 70.45%, SD: 1.88%)
#
# ZVa9ccluster34, shape:  (11053, 13) (11053,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.43%
# CV Acc: 68.01%, SD: 6.71%)
#
# ZVa9ccluster35, shape:  (9119, 13) (9119,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.89%
# CV Acc: 68.75%, SD: 3.95%)
#
# vehicle_type : ZVa78
# ZVa78cluster0, shape:  (282633, 13) (282633,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 82.13%
# CV Acc: 70.00%, SD: 0.67%)
#
# ZVa78cluster1, shape:  (255306, 13) (255306,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 78.53%
# CV Acc: 67.49%, SD: 0.93%)
#
# ZVa78cluster2, shape:  (4533, 13) (4533,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.78%
# CV Acc: 92.39%, SD: 5.11%)
#
# ZVa78 cluster3: 0 record, skip.
# ZVa78cluster4, shape:  (71, 13) (71,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.96%
# CV Acc: 42.19%, SD: 11.62%)
#
# ZVa78cluster5, shape:  (131, 13) (131,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.71%
# CV Acc: 62.51%, SD: 13.79%)
#
# ZVa78 cluster6: only has positive samples
# ZVa78 cluster7: 0 record, skip.
# ZVa78 cluster8: 0 record, skip.
# ZVa78 cluster9: 0 record, skip.
# ZVa78 cluster10: 0 record, skip.
# ZVa78 cluster11: 0 record, skip.
# ZVa78cluster12, shape:  (3648, 13) (3648,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.03%
# CV Acc: 64.97%, SD: 2.72%)
#
# ZVa78cluster13, shape:  (5668, 13) (5668,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.77%
# CV Acc: 63.60%, SD: 4.80%)
#
# ZVa78cluster14, shape:  (104, 13) (104,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.04%
# CV Acc: 92.38%, SD: 7.74%)
#
# ZVa78 cluster15: 0 record, skip.
# ZVa78cluster16, shape:  (88888, 13) (88888,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.05%
# CV Acc: 70.24%, SD: 1.08%)
#
# ZVa78cluster17, shape:  (357558, 13) (357558,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 80.37%
# CV Acc: 67.65%, SD: 1.04%)
#
# ZVa78cluster18, shape:  (4647, 13) (4647,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.87%
# CV Acc: 91.48%, SD: 6.93%)
#
# ZVa78 cluster19: 0 record, skip.
# ZVa78cluster20, shape:  (1542, 13) (1542,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.25%
# CV Acc: 57.84%, SD: 5.63%)
#
# ZVa78cluster21, shape:  (4902, 13) (4902,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.25%
# CV Acc: 60.28%, SD: 5.35%)
#
# ZVa78cluster22, shape:  (519, 13) (519,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.61%
# CV Acc: 99.04%, SD: 0.86%)
#
# ZVa78 cluster23: 0 record, skip.
# ZVa78cluster24, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 90.91%
# CV Acc: 61.39%, SD: 16.49%)
#
# ZVa78cluster25, shape:  (96, 13) (96,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.92%
# CV Acc: 72.63%, SD: 37.28%)
#
# ZVa78 cluster26: 0 record, skip.
# ZVa78 cluster27: 0 record, skip.
# ZVa78cluster28, shape:  (815, 13) (815,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.26%
# CV Acc: 67.24%, SD: 7.33%)
#
# ZVa78cluster29, shape:  (2362, 13) (2362,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.77%
# CV Acc: 68.09%, SD: 10.61%)
#
# ZVa78cluster30, shape:  (40, 13) (40,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.50%
# CV Acc: 97.50%, SD: 5.00%)
#
# ZVa78 cluster31: 0 record, skip.
# ZVa78cluster32, shape:  (25526, 13) (25526,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.27%
# CV Acc: 69.13%, SD: 2.71%)
#
# ZVa78cluster33, shape:  (47927, 13) (47927,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.41%
# CV Acc: 70.29%, SD: 1.33%)
#
# ZVa78cluster34, shape:  (4425, 13) (4425,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.98%
# CV Acc: 97.85%, SD: 0.83%)
#
# ZVa78 cluster35: 0 record, skip.
# vehicle_type : ZV252
# ZV252cluster0, shape:  (7980, 13) (7980,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.32%
# CV Acc: 82.63%, SD: 3.04%)
#
# ZV252cluster1, shape:  (1144, 13) (1144,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.48%
# CV Acc: 67.31%, SD: 6.31%)
#
# ZV252cluster2, shape:  (17985, 13) (17985,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.69%
# CV Acc: 76.74%, SD: 3.66%)
#
# ZV252cluster3, shape:  (6484, 13) (6484,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.75%
# CV Acc: 87.68%, SD: 8.74%)
#
# ZV252 cluster4: 0 record, skip.
# ZV252 cluster5: 0 record, skip.
# ZV252 cluster6: only has positive samples
# ZV252 cluster7: 0 record, skip.
# ZV252 cluster8: 0 record, skip.
# ZV252 cluster9: 0 record, skip.
# ZV252 cluster10: 0 record, skip.
# ZV252 cluster11: 0 record, skip.
# ZV252cluster12, shape:  (16, 13) (16,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 81.25%
# CV Acc: 51.67%, SD: 28.09%)
#
# ZV252cluster13, shape:  (22, 13) (22,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 71.00%, SD: 29.73%)
#
# ZV252cluster14, shape:  (138, 13) (138,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.10%
# CV Acc: 60.82%, SD: 6.99%)
#
# ZV252cluster15, shape:  (67, 13) (67,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.54%
# CV Acc: 62.64%, SD: 24.78%)
#
# ZV252cluster16, shape:  (1103, 13) (1103,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.46%
# CV Acc: 74.81%, SD: 8.54%)
#
# ZV252cluster17, shape:  (387, 13) (387,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.97%
# CV Acc: 65.14%, SD: 5.41%)
#
# ZV252cluster18, shape:  (26283, 13) (26283,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.28%
# CV Acc: 75.55%, SD: 5.73%)
#
# ZV252cluster19, shape:  (4607, 13) (4607,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.52%
# CV Acc: 86.21%, SD: 6.69%)
#
# ZV252 cluster20: only has negative samples
# ZV252cluster21, shape:  (8, 13) (8,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 62.50%
# CV Acc: 50.00%, SD: 44.72%)
#
# ZV252cluster22, shape:  (93, 13) (93,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.77%
# CV Acc: 67.49%, SD: 19.70%)
#
# ZV252cluster23, shape:  (82, 13) (82,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 65.88%, SD: 4.66%)
#
# ZV252 cluster24: 0 record, skip.
# ZV252 cluster25: 0 record, skip.
# ZV252 cluster26: 0 record, skip.
# ZV252 cluster27: 0 record, skip.
# ZV252 cluster28: 0 record, skip.
# ZV252 cluster29: 0 record, skip.
# ZV252 cluster30: 0 record, skip.
# ZV252 cluster31: only has negative samples
# ZV252cluster32, shape:  (95, 13) (95,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 90.53%
# CV Acc: 90.53%, SD: 9.65%)
#
# ZV252cluster33, shape:  (142, 13) (142,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.48%
# CV Acc: 50.00%, SD: 11.35%)
#
# ZV252cluster34, shape:  (1107, 13) (1107,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.01%
# CV Acc: 69.63%, SD: 15.62%)
#
# ZV252cluster35, shape:  (1519, 13) (1519,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.41%
# CV Acc: 84.47%, SD: 8.85%)

# %% [markdown]
# # Refresh status of the weak models

# %%
def retrieve_status(vehicle_type, cn=0):
    print('vehicle_type :',vehicle_type)
    model_path = '../models/final'
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    model_path = model_path +'/'+  vehicle_type
    if not os.path.exists(model_path):
        os.makedirs(model_path)
    
    status_indicator = list()
    #status:
    ok = 2
    not_found = 0.5
    pos = 1
    neg = 0
    for i in range(cn, n_clusters):
        
        #load data
        sample = pd.read_csv('../data/final/clusters/' + vehicle_type + '/cluster' + str(i) + '.csv')
        if len(sample) == 0:
            print(vehicle_type+' cluster'+str(i)+': 0 record, skip.')
            status_indicator.append(not_found)
            continue
        sample_= sample[sample.iloc[: , -1]==0]
        if len(sample_) == 0 or len(sample_) == len(sample):
            note = vehicle_type+' cluster'+str(i)+': only has negative samples'
            if len(sample_) == 0:
                status_indicator.append(pos)
                note = vehicle_type+' cluster'+str(i)+': only has positive samples'
            else:
                status_indicator.append(neg)
            print(note)
            continue
        status_indicator.append(ok)
    arr = np.array(status_indicator)
    np.savetxt(model_path+"/status.csv", arr, delimiter=",")

for vehicle_type in vehicle_types:
        retrieve_status(vehicle_type, 0)
# Out:
# vehicle_type : ZVe44
# ZVe44 cluster6: only has positive samples
# ZVe44 cluster7: 0 record, skip.
# ZVe44 cluster8: only has positive samples
# ZVe44 cluster9: only has positive samples
# ZVe44 cluster10: 0 record, skip.
# ZVe44 cluster11: 0 record, skip.
# ZVe44 cluster27: only has positive samples
# vehicle_type : ZV573
# ZV573 cluster8: only has negative samples
# ZV573 cluster9: 0 record, skip.
# ZV573 cluster10: 0 record, skip.
# ZV573 cluster11: 0 record, skip.
# ZV573 cluster27: only has negative samples
# vehicle_type : ZV63d
# ZV63d cluster9: only has negative samples
# ZV63d cluster10: 0 record, skip.
# ZV63d cluster11: 0 record, skip.
# ZV63d cluster25: only has positive samples
# ZV63d cluster26: 0 record, skip.
# ZV63d cluster27: only has positive samples
# vehicle_type : ZVfd4
# ZVfd4 cluster4: only has positive samples
# ZVfd4 cluster5: 0 record, skip.
# ZVfd4 cluster7: only has positive samples
# ZVfd4 cluster8: 0 record, skip.
# ZVfd4 cluster9: 0 record, skip.
# ZVfd4 cluster10: 0 record, skip.
# ZVfd4 cluster11: 0 record, skip.
# ZVfd4 cluster24: 0 record, skip.
# ZVfd4 cluster25: 0 record, skip.
# ZVfd4 cluster26: 0 record, skip.
# ZVfd4 cluster27: 0 record, skip.
# vehicle_type : ZVa9c
# ZVa9c cluster7: 0 record, skip.
# ZVa9c cluster8: 0 record, skip.
# ZVa9c cluster9: 0 record, skip.
# ZVa9c cluster10: 0 record, skip.
# ZVa9c cluster11: 0 record, skip.
# ZVa9c cluster24: only has negative samples
# ZVa9c cluster25: 0 record, skip.
# ZVa9c cluster26: only has positive samples
# ZVa9c cluster27: only has negative samples
# vehicle_type : ZVa78
# ZVa78 cluster3: 0 record, skip.
# ZVa78 cluster6: only has positive samples
# ZVa78 cluster7: 0 record, skip.
# ZVa78 cluster8: 0 record, skip.
# ZVa78 cluster9: 0 record, skip.
# ZVa78 cluster10: 0 record, skip.
# ZVa78 cluster11: 0 record, skip.
# ZVa78 cluster15: 0 record, skip.
# ZVa78 cluster19: 0 record, skip.
# ZVa78 cluster23: 0 record, skip.
# ZVa78 cluster26: 0 record, skip.
# ZVa78 cluster27: 0 record, skip.
# ZVa78 cluster31: 0 record, skip.
# ZVa78 cluster35: 0 record, skip.
# vehicle_type : ZV252
# ZV252 cluster4: 0 record, skip.
# ZV252 cluster5: 0 record, skip.
# ZV252 cluster6: only has positive samples
# ZV252 cluster7: 0 record, skip.
# ZV252 cluster8: 0 record, skip.
# ZV252 cluster9: 0 record, skip.
# ZV252 cluster10: 0 record, skip.
# ZV252 cluster11: 0 record, skip.
# ZV252 cluster20: only has negative samples
# ZV252 cluster24: 0 record, skip.
# ZV252 cluster25: 0 record, skip.
# ZV252 cluster26: 0 record, skip.
# ZV252 cluster27: 0 record, skip.
# ZV252 cluster28: 0 record, skip.
# ZV252 cluster29: 0 record, skip.
# ZV252 cluster30: 0 record, skip.
# ZV252 cluster31: only has negative samples

# %% [markdown]
# ## Tuning Evidence

# %% [markdown]
# [eta= 0.05 ,gamma= 0.5 ,max_depth= 8 ]
# Train Acc: 68.84%
# CV Acc: 65.15%, SD: 1.12%)
#
# [eta= 0.05 ,gamma= 0.9 ,max_depth= 8 ]
# Train Acc: 69.05%
# CV Acc: 65.13%, SD: 1.12%)
#
# [eta= 0.05 ,gamma= 1.2 ,max_depth= 8 ]
# Train Acc: 69.06%
# CV Acc: 65.19%, SD: 1.15%)
#
# [eta= 0.05 ,gamma= 1.5 ,max_depth= 8 ]
# Train Acc: 68.85%
# CV Acc: 65.22%, SD: 1.05%)
#
# [eta= 0.05 ,gamma= 0.5 ,max_depth= 10 ]
# Train Acc: 72.05%
# CV Acc: 66.72%, SD: 0.82%)
#
# [eta= 0.05 ,gamma= 0.9 ,max_depth= 10 ]
# Train Acc: 71.90%
# CV Acc: 66.76%, SD: 0.76%)
#
# [eta= 0.05 ,gamma= 1.2 ,max_depth= 10 ]
# Train Acc: 72.05%
# CV Acc: 66.87%, SD: 0.77%)
#
# [eta= 0.05 ,gamma= 1.5 ,max_depth= 10 ]
# Train Acc: 71.94%
# CV Acc: 66.89%, SD: 0.75%)
#
# [eta= 0.05 ,gamma= 0.5 ,max_depth= 13 ]
# Train Acc: 76.66%
# CV Acc: 68.29%, SD: 0.71%)
#
# [eta= 0.05 ,gamma= 0.9 ,max_depth= 13 ]
# Train Acc: 76.82%
# CV Acc: 68.30%, SD: 0.69%)
#
# [eta= 0.05 ,gamma= 1.2 ,max_depth= 13 ]
# Train Acc: 76.72%
# CV Acc: 68.32%, SD: 0.70%)
#
# [eta= 0.05 ,gamma= 1.5 ,max_depth= 13 ]
# Train Acc: 76.86%
# CV Acc: 68.30%, SD: 0.73%)

# %% [markdown]
# vehicle_type : ZVe44
# ZVe44cluster0, shape:  (580695, 13) (580695,)
#
#
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 76.55%
# CV Acc: 68.32%, SD: 0.72%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 76.20%
# CV Acc: 68.31%, SD: 0.68%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 75.91%
# CV Acc: 68.19%, SD: 0.68%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 75.23%
# CV Acc: 68.02%, SD: 0.62%)
#
# ZVe44cluster1, shape:  (453163, 13) (453163,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 77.87%
# CV Acc: 67.74%, SD: 1.30%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 77.29%
# CV Acc: 67.65%, SD: 1.32%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 77.00%
# CV Acc: 67.72%, SD: 1.31%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 75.38%
# CV Acc: 67.52%, SD: 1.28%)
#
# ZVe44cluster2, shape:  (34899, 13) (34899,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.60%
# CV Acc: 67.12%, SD: 0.92%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 89.86%
# CV Acc: 67.15%, SD: 1.01%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 86.90%
# CV Acc: 66.55%, SD: 1.07%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 82.92%
# CV Acc: 65.81%, SD: 1.42%)
#
# ZVe44cluster3, shape:  (7959, 13) (7959,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.42%
# CV Acc: 76.39%, SD: 3.13%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 96.62%
# CV Acc: 76.27%, SD: 3.78%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 94.20%
# CV Acc: 75.17%, SD: 2.95%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 92.02%
# CV Acc: 74.52%, SD: 2.21%)
#
# ZVe44cluster4, shape:  (104, 13) (104,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.12%
# CV Acc: 59.86%, SD: 22.09%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 95.19%
# CV Acc: 59.81%, SD: 21.24%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 92.31%
# CV Acc: 60.76%, SD: 21.84%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 70.19%
# CV Acc: 66.57%, SD: 27.02%)
#
# ZVe44cluster5, shape:  (214, 13) (214,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.20%
# CV Acc: 77.14%, SD: 20.48%)
#
# [eta= 0.05 ,gamma= 5 ,max_depth= 13 ]
# Train Acc: 94.86%
# CV Acc: 77.13%, SD: 17.83%)
#
# [eta= 0.05 ,gamma= 10 ,max_depth= 13 ]
# Train Acc: 92.99%
# CV Acc: 70.49%, SD: 19.54%)
#
# [eta= 0.05 ,gamma= 20 ,max_depth= 13 ]
# Train Acc: 85.51%
# CV Acc: 56.28%, SD: 32.50%)

# %%
for vehicle_type in vehicle_types:
    xgboost_train(vehicle_type,0)
# Out:
# vehicle_type : ZVfd4
# ZVfd4cluster0, shape:  (34940, 13) (34940,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.55%
# CV Acc: 83.20%, SD: 1.66%)
#
# ZVfd4cluster1, shape:  (7489, 13) (7489,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.32%
# CV Acc: 79.72%, SD: 4.92%)
#
# ZVfd4cluster2, shape:  (11501, 13) (11501,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.23%
# CV Acc: 71.25%, SD: 3.00%)
#
# ZVfd4cluster3, shape:  (4861, 13) (4861,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.59%
# CV Acc: 80.19%, SD: 6.00%)
#
# ZVfd4 cluster4: only has positive samples
# ZVfd4 cluster5: 0 record, skip.
# ZVfd4cluster6, shape:  (2, 13) (2,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 50.00%
# CV Acc: 0.00%, SD: 0.00%)
#
# ZVfd4 cluster7: only has positive samples
# ZVfd4 cluster8: 0 record, skip.
# ZVfd4 cluster9: 0 record, skip.
# ZVfd4 cluster10: 0 record, skip.
# ZVfd4 cluster11: 0 record, skip.
# ZVfd4cluster12, shape:  (415, 13) (415,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.31%
# CV Acc: 64.34%, SD: 4.91%)
#
# ZVfd4cluster13, shape:  (137, 13) (137,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.62%
# CV Acc: 77.28%, SD: 9.35%)
#
# ZVfd4cluster14, shape:  (120, 13) (120,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.00%
# CV Acc: 43.33%, SD: 8.16%)
#
# ZVfd4cluster15, shape:  (41, 13) (41,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 43.89%, SD: 18.54%)
#
# ZVfd4cluster16, shape:  (10447, 13) (10447,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.70%
# CV Acc: 82.62%, SD: 4.51%)
#
# ZVfd4cluster17, shape:  (11133, 13) (11133,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.32%
# CV Acc: 78.98%, SD: 2.94%)
#
# ZVfd4cluster18, shape:  (21975, 13) (21975,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.01%
# CV Acc: 69.78%, SD: 4.84%)
#
# ZVfd4cluster19, shape:  (3140, 13) (3140,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.52%
# CV Acc: 72.71%, SD: 5.47%)
#
# ZVfd4cluster20, shape:  (150, 13) (150,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.33%
# CV Acc: 68.67%, SD: 19.16%)
#
# ZVfd4cluster21, shape:  (78, 13) (78,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.59%
# CV Acc: 62.67%, SD: 26.75%)
#
# ZVfd4cluster22, shape:  (312, 13) (312,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.44%
# CV Acc: 71.54%, SD: 15.36%)
#
# ZVfd4cluster23, shape:  (137, 13) (137,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.70%
# CV Acc: 64.10%, SD: 11.90%)
#
# ZVfd4 cluster24: 0 record, skip.
# ZVfd4 cluster25: 0 record, skip.
# ZVfd4 cluster26: 0 record, skip.
# ZVfd4 cluster27: 0 record, skip.
# ZVfd4cluster28, shape:  (153, 13) (153,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.35%
# CV Acc: 76.69%, SD: 27.88%)
#
# ZVfd4cluster29, shape:  (156, 13) (156,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.36%
# CV Acc: 77.42%, SD: 31.61%)
#
# ZVfd4cluster30, shape:  (304, 13) (304,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.68%
# CV Acc: 84.23%, SD: 15.39%)
#
# ZVfd4cluster31, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.73%
# CV Acc: 88.89%, SD: 17.21%)
#
# ZVfd4cluster32, shape:  (4936, 13) (4936,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.17%
# CV Acc: 80.67%, SD: 2.62%)
#
# ZVfd4cluster33, shape:  (1798, 13) (1798,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.56%
# CV Acc: 74.03%, SD: 6.86%)
#
# ZVfd4cluster34, shape:  (4800, 13) (4800,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.25%
# CV Acc: 65.38%, SD: 8.85%)
#
# ZVfd4cluster35, shape:  (2423, 13) (2423,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.34%
# CV Acc: 72.59%, SD: 11.54%)
#
# vehicle_type : ZVa9c
# ZVa9ccluster0, shape:  (96987, 13) (96987,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.46%
# CV Acc: 74.16%, SD: 0.57%)
#
# ZVa9ccluster1, shape:  (60428, 13) (60428,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.86%
# CV Acc: 69.58%, SD: 2.72%)
#
# ZVa9ccluster2, shape:  (32105, 13) (32105,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 93.72%
# CV Acc: 67.17%, SD: 0.75%)
#
# ZVa9ccluster3, shape:  (11064, 13) (11064,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.60%
# CV Acc: 72.97%, SD: 2.62%)
#
# ZVa9ccluster4, shape:  (27, 13) (27,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.59%
# CV Acc: 37.33%, SD: 16.79%)
#
# ZVa9ccluster5, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 88.64%
# CV Acc: 58.89%, SD: 11.97%)
#
# ZVa9ccluster6, shape:  (18, 13) (18,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 77.78%
# CV Acc: 60.00%, SD: 16.16%)
#
# ZVa9c cluster7: 0 record, skip.
# ZVa9c cluster8: 0 record, skip.
# ZVa9c cluster9: 0 record, skip.
# ZVa9c cluster10: 0 record, skip.
# ZVa9c cluster11: 0 record, skip.
# ZVa9ccluster12, shape:  (865, 13) (865,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.38%
# CV Acc: 67.51%, SD: 4.50%)
#
# ZVa9ccluster13, shape:  (1026, 13) (1026,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.15%
# CV Acc: 64.73%, SD: 6.36%)
#
# ZVa9ccluster14, shape:  (320, 13) (320,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.81%
# CV Acc: 62.50%, SD: 8.09%)
#
# ZVa9ccluster15, shape:  (159, 13) (159,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.23%
# CV Acc: 44.54%, SD: 14.63%)
#
# ZVa9ccluster16, shape:  (40402, 13) (40402,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.31%
# CV Acc: 74.35%, SD: 2.62%)
#
# ZVa9ccluster17, shape:  (88835, 13) (88835,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.73%
# CV Acc: 66.89%, SD: 1.97%)
#
# ZVa9ccluster18, shape:  (105813, 13) (105813,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.85%
# CV Acc: 69.27%, SD: 1.70%)
#
# ZVa9ccluster19, shape:  (12398, 13) (12398,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.91%
# CV Acc: 67.38%, SD: 2.13%)
#
# ZVa9ccluster20, shape:  (652, 13) (652,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.23%
# CV Acc: 59.68%, SD: 5.73%)
#
# ZVa9ccluster21, shape:  (1079, 13) (1079,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.52%
# CV Acc: 66.72%, SD: 7.70%)
#
# ZVa9ccluster22, shape:  (1224, 13) (1224,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.28%
# CV Acc: 52.29%, SD: 6.55%)
#
# ZVa9ccluster23, shape:  (733, 13) (733,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.64%
# CV Acc: 61.68%, SD: 4.53%)
#
# ZVa9c cluster24: only has negative samples
# ZVa9c cluster25: 0 record, skip.
# ZVa9c cluster26: only has positive samples
# ZVa9c cluster27: only has negative samples
# ZVa9ccluster28, shape:  (37, 13) (37,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.19%
# CV Acc: 55.71%, SD: 28.29%)
#
# ZVa9ccluster29, shape:  (101, 13) (101,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.05%
# CV Acc: 78.29%, SD: 17.08%)
#
# ZVa9ccluster30, shape:  (121, 13) (121,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 91.74%
# CV Acc: 63.50%, SD: 10.92%)
#
# ZVa9ccluster31, shape:  (58, 13) (58,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.55%
# CV Acc: 81.06%, SD: 21.31%)
#
# ZVa9ccluster32, shape:  (11333, 13) (11333,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.00%
# CV Acc: 75.66%, SD: 2.96%)
#
# ZVa9ccluster33, shape:  (8988, 13) (8988,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.62%
# CV Acc: 70.45%, SD: 1.88%)
#
# ZVa9ccluster34, shape:  (11053, 13) (11053,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.43%
# CV Acc: 68.01%, SD: 6.71%)
#
# ZVa9ccluster35, shape:  (9119, 13) (9119,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.89%
# CV Acc: 68.75%, SD: 3.95%)
#
# vehicle_type : ZVa78
# ZVa78cluster0, shape:  (282633, 13) (282633,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 82.13%
# CV Acc: 70.00%, SD: 0.67%)
#
# ZVa78cluster1, shape:  (255306, 13) (255306,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 78.53%
# CV Acc: 67.49%, SD: 0.93%)
#
# ZVa78cluster2, shape:  (4533, 13) (4533,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.78%
# CV Acc: 92.39%, SD: 5.11%)
#
# ZVa78 cluster3: 0 record, skip.
# ZVa78cluster4, shape:  (71, 13) (71,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.96%
# CV Acc: 42.19%, SD: 11.62%)
#
# ZVa78cluster5, shape:  (131, 13) (131,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.71%
# CV Acc: 62.51%, SD: 13.79%)
#
# ZVa78 cluster6: only has positive samples
# ZVa78 cluster7: 0 record, skip.
# ZVa78 cluster8: 0 record, skip.
# ZVa78 cluster9: 0 record, skip.
# ZVa78 cluster10: 0 record, skip.
# ZVa78 cluster11: 0 record, skip.
# ZVa78cluster12, shape:  (3648, 13) (3648,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.03%
# CV Acc: 64.97%, SD: 2.72%)
#
# ZVa78cluster13, shape:  (5668, 13) (5668,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 95.77%
# CV Acc: 63.60%, SD: 4.80%)
#
# ZVa78cluster14, shape:  (104, 13) (104,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.04%
# CV Acc: 92.38%, SD: 7.74%)
#
# ZVa78 cluster15: 0 record, skip.
# ZVa78cluster16, shape:  (88888, 13) (88888,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 89.05%
# CV Acc: 70.24%, SD: 1.08%)
#
# ZVa78cluster17, shape:  (357558, 13) (357558,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 80.37%
# CV Acc: 67.65%, SD: 1.04%)
#
# ZVa78cluster18, shape:  (4647, 13) (4647,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.87%
# CV Acc: 91.48%, SD: 6.93%)
#
# ZVa78 cluster19: 0 record, skip.
# ZVa78cluster20, shape:  (1542, 13) (1542,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.25%
# CV Acc: 57.84%, SD: 5.63%)
#
# ZVa78cluster21, shape:  (4902, 13) (4902,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.25%
# CV Acc: 60.28%, SD: 5.35%)
#
# ZVa78cluster22, shape:  (519, 13) (519,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.61%
# CV Acc: 99.04%, SD: 0.86%)
#
# ZVa78 cluster23: 0 record, skip.
# ZVa78cluster24, shape:  (44, 13) (44,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 90.91%
# CV Acc: 61.39%, SD: 16.49%)
#
# ZVa78cluster25, shape:  (96, 13) (96,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.92%
# CV Acc: 72.63%, SD: 37.28%)
#
# ZVa78 cluster26: 0 record, skip.
# ZVa78 cluster27: 0 record, skip.
# ZVa78cluster28, shape:  (815, 13) (815,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.26%
# CV Acc: 67.24%, SD: 7.33%)
#
# ZVa78cluster29, shape:  (2362, 13) (2362,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.77%
# CV Acc: 68.09%, SD: 10.61%)
#
# ZVa78cluster30, shape:  (40, 13) (40,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.50%
# CV Acc: 97.50%, SD: 5.00%)
#
# ZVa78 cluster31: 0 record, skip.
# ZVa78cluster32, shape:  (25526, 13) (25526,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.27%
# CV Acc: 69.13%, SD: 2.71%)
#
# ZVa78cluster33, shape:  (47927, 13) (47927,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.41%
# CV Acc: 70.29%, SD: 1.33%)
#
# ZVa78cluster34, shape:  (4425, 13) (4425,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.98%
# CV Acc: 97.85%, SD: 0.83%)
#
# ZVa78 cluster35: 0 record, skip.
# vehicle_type : ZV252
# ZV252cluster0, shape:  (7980, 13) (7980,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.32%
# CV Acc: 82.63%, SD: 3.04%)
#
# ZV252cluster1, shape:  (1144, 13) (1144,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.48%
# CV Acc: 67.31%, SD: 6.31%)
#
# ZV252cluster2, shape:  (17985, 13) (17985,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.69%
# CV Acc: 76.74%, SD: 3.66%)
#
# ZV252cluster3, shape:  (6484, 13) (6484,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.75%
# CV Acc: 87.68%, SD: 8.74%)
#
# ZV252 cluster4: 0 record, skip.
# ZV252 cluster5: 0 record, skip.
# ZV252 cluster6: only has positive samples
# ZV252 cluster7: 0 record, skip.
# ZV252 cluster8: 0 record, skip.
# ZV252 cluster9: 0 record, skip.
# ZV252 cluster10: 0 record, skip.
# ZV252 cluster11: 0 record, skip.
# ZV252cluster12, shape:  (16, 13) (16,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 81.25%
# CV Acc: 51.67%, SD: 28.09%)
#
# ZV252cluster13, shape:  (22, 13) (22,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 71.00%, SD: 29.73%)
#
# ZV252cluster14, shape:  (138, 13) (138,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.10%
# CV Acc: 60.82%, SD: 6.99%)
#
# ZV252cluster15, shape:  (67, 13) (67,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 92.54%
# CV Acc: 62.64%, SD: 24.78%)
#
# ZV252cluster16, shape:  (1103, 13) (1103,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 97.46%
# CV Acc: 74.81%, SD: 8.54%)
#
# ZV252cluster17, shape:  (387, 13) (387,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.97%
# CV Acc: 65.14%, SD: 5.41%)
#
# ZV252cluster18, shape:  (26283, 13) (26283,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 98.28%
# CV Acc: 75.55%, SD: 5.73%)
#
# ZV252cluster19, shape:  (4607, 13) (4607,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.52%
# CV Acc: 86.21%, SD: 6.69%)
#
# ZV252 cluster20: only has negative samples
# ZV252cluster21, shape:  (8, 13) (8,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 62.50%
# CV Acc: 50.00%, SD: 44.72%)
#
# ZV252cluster22, shape:  (93, 13) (93,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.77%
# CV Acc: 67.49%, SD: 19.70%)
#
# ZV252cluster23, shape:  (82, 13) (82,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 100.00%
# CV Acc: 65.88%, SD: 4.66%)
#
# ZV252 cluster24: 0 record, skip.
# ZV252 cluster25: 0 record, skip.
# ZV252 cluster26: 0 record, skip.
# ZV252 cluster27: 0 record, skip.
# ZV252 cluster28: 0 record, skip.
# ZV252 cluster29: 0 record, skip.
# ZV252 cluster30: 0 record, skip.
# ZV252 cluster31: only has negative samples
# ZV252cluster32, shape:  (95, 13) (95,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 90.53%
# CV Acc: 90.53%, SD: 9.65%)
#
# ZV252cluster33, shape:  (142, 13) (142,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 96.48%
# CV Acc: 50.00%, SD: 11.35%)
#
# ZV252cluster34, shape:  (1107, 13) (1107,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.01%
# CV Acc: 69.63%, SD: 15.62%)
#
# ZV252cluster35, shape:  (1519, 13) (1519,)
# [eta= 0.05 ,gamma= 2 ,max_depth= 13 ]
# Train Acc: 99.41%
# CV Acc: 84.47%, SD: 8.85%)
